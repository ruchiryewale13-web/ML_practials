# %% [markdown]
# <a href="https://colab.research.google.com/github/ruchiryewale13-web/ML_practials/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def user_services():
  print('''
      1. Create New User
      2. Update User
      3. Delete User
      4. Display All Users
      5. Display User By Id
      0. Exit
  ''')

# %%
student_database = {}

# %%
import random
import time

def loading(seconds):
  print("Loading...", end='')
  for _ in range(seconds):
    time.sleep(1)
    print(".", end='')
  print("\n")

def create_new_user(student_database):
  name = input('Enter Your Name : ')
  age = input('Enter Your Age : ')
  gender = input('Enter Your Gender : ')
  random = 0
  if name != '' and age != '' and gender != '':
    system_generated_otp = random.randint(1000, 9999)
    loading(3)
    print('OTP SMS : ', system_generated_otp)
    while True:
      user_otp = int(input('Enter OTP : '))
      if user_otp == system_generated_otp:
        print('✅')
        student_database[student_id] = [name, age, gender]
        print(f'Congrats....{name}, Your Student Id : {student_id}')
        student_id += 1
        break
      else:
        print('Invalid OTP...')
  else:
    print('Please Fill the whole info...')

# %%
student_id = 1

while True:
  user_services()

  user_choise = int(input('Select Any Operation : '))

  if user_choise == 1:
    create_new_user(student_database)
    # new user

  elif user_choise == 2:
    # update user
    pass
  elif user_choise == 3:
    # delete user
    pass
  elif user_choise == 4:
    # display all data
    pass
  elif user_choise == 5:
    # diplay by id
    pass
  elif user_choise == 0:
    print('Thanks For Using....')
    break
  else:
    print('Inavlid Operations...')
# Out:
#       1. Create New User
#       2. Update User
#       3. Delete User
#       4. Display All Users
#       5. Display User By Id
#       0. Exit
