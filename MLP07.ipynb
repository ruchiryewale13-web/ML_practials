# %% [markdown]
# <a href="https://colab.research.google.com/github/ruchiryewale13-web/ML_practials/blob/main/MLP07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# RUCHIR YEWALE CS23133
#
# AIM:  To apply support vector machine for classification and analyse the impact of difference kernel on model accuracy

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = "/content/drive/MyDrive/pulsar_stars.csv"
df=pd.read_csv(path)
df.head(5)
# Out:
#     Mean of the integrated profile  \
# 0                       140.562500
# 1                       102.507812
# 2                       103.015625
# 3                       136.750000
# 4                        88.726562
#
#     Standard deviation of the integrated profile  \
# 0                                      55.683782
# 1                                      58.882430
# 2                                      39.341649
# 3                                      57.178449
# 4                                      40.672225
#
#     Excess kurtosis of the integrated profile  \
# 0                                   -0.234571
# 1                                    0.465318
# 2                                    0.323328
# 3                                   -0.068415
# 4                                    0.600866
#
#     Skewness of the integrated profile   Mean of the DM-SNR curve  \
# 0                            -0.699648                   3.199833
# ...

# %%
df.columns
# Out:
# Index([' Mean of the integrated profile',
#        ' Standard deviation of the integrated profile',
#        ' Excess kurtosis of the integrated profile',
#        ' Skewness of the integrated profile', ' Mean of the DM-SNR curve',
#        ' Standard deviation of the DM-SNR curve',
#        ' Excess kurtosis of the DM-SNR curve', ' Skewness of the DM-SNR curve',
#        'target_class'],
#       dtype='object')

# %%
df.rename(columns={
    'Mean_of_the_integrated_profile': 'Mean_IP',
    'Standard_deviation_of_the_integrated_profile': 'Std_IP',
    'Excess_kurtosis_of_the_integrated_profile': 'EK_IP',
    'Skewness_of_the_integrated_profile': 'Skew_IP',
    'Mean_of_the_DM-SNR_curve': 'Mean_DMSNR',
    'Standard_deviation_of_the_DM-SNR_curve': 'Std_DMSNR',
    'Excess_kurtosis_of_the_DM-SNR_curve': 'EK_DMSNR',
    'Skewness_of_the_DM-SNR_curve': 'Skew_DMSNR'
}, inplace=True)
df.head(5)
# Out:
#       Mean_IP     Std_IP     EK_IP   Skew_IP  Mean_DMSNR  Std_DMSNR  \
# 0  140.562500  55.683782 -0.234571 -0.699648    3.199833  19.110426
# 1  102.507812  58.882430  0.465318 -0.515088    1.677258  14.860146
# 2  103.015625  39.341649  0.323328  1.051164    3.121237  21.744669
# 3  136.750000  57.178449 -0.068415 -0.636238    3.642977  20.959280
# 4   88.726562  40.672225  0.600866  1.123492    1.178930  11.468720
#
#     EK_DMSNR  Skew_DMSNR  target_class
# 0   7.975532   74.242225             0
# 1  10.576487  127.393580             0
# 2   7.735822   63.171909             0
# 3   6.896499   53.593661             0
# 4  14.269573  252.567306             0

# %%
class_counts = df['target_class'].value_counts()
print('Class Counts:')
print(class_counts)

class_percentages = df['target_class'].value_counts(normalize=True) * 100
print('\nClass Percentages:')
print(class_percentages)
# Out:
# Class Counts:
# target_class
# 0    16259
# 1     1639
# Name: count, dtype: int64
#
# Class Percentages:
# target_class
# 0    90.842552
# 1     9.157448
# Name: proportion, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X = df.drop(['target_class'], axis=1)
y = df['target_class']

# %%
from sklearn.model_selection import train_test_split

X = df.drop(['target_class'], axis=1)
y = df['target_class']

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
cols = x_train.columns
print(cols)
# Out:
# Index(['Mean_IP', 'Std_IP', 'EK_IP', 'Skew_IP', 'Mean_DMSNR', 'Std_DMSNR',
#        'EK_DMSNR', 'Skew_DMSNR'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)
print("feature scaled successfully")
# Out:
# feature scaled successfully

# %%
x_train
# Out:
#           Mean_IP     Std_IP     EK_IP   Skew_IP  Mean_DMSNR  Std_DMSNR  \
# 14453  108.765625  47.520470  0.191285  0.007945    2.921405  18.009581
# 15797  121.554688  50.909357  0.083099 -0.087226    1.098662  11.590431
# 4510   100.265625  43.808975  0.233088  0.451613    1.142977  13.774721
# 11899  118.460938  41.178518  0.162482  1.050363    1.161371  13.353561
# 895     97.109375  35.920319  0.364792  2.250635    2.826923  17.559245
# ...           ...        ...       ...       ...         ...        ...
# 11284  124.312500  53.179053 -0.012418 -0.556021    7.186455  29.308266
# 11964  115.617188  46.784600  0.218177  0.226757    6.140468  30.271961
# 5390   116.031250  43.213846  0.663456  0.433088    0.785117  11.628149
# 860    135.664062  49.933749 -0.089940 -0.226726    3.859532  21.501505
# 15795  120.726562  50.472256  0.346178  0.184797    0.769231  11.792603
#
#         EK_DMSNR  Skew_DMSNR
# 14453   8.468258   84.137111
# 15797  14.180137  242.867752
# ...

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# Initialize the SVM classifier with RBF kernel
svm_rbf = SVC(kernel='rbf', random_state=42)

# Train the model
svm_rbf.fit(x_train_scaled, y_train)

# Make predictions on the scaled test set
y_pred_rbf = svm_rbf.predict(x_test_scaled)

# Evaluate the model
accuracy_rbf = accuracy_score(y_test, y_pred_rbf)
print(f'Accuracy with RBF kernel: {accuracy_rbf:.4f}')
# Out:
# Accuracy with RBF kernel: 0.9796

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# Initialize the SVM classifier with RBF kernel and C=100
svm_rbf_c100 = SVC(kernel='rbf', C=100, random_state=42)

# Train the model
svm_rbf_c100.fit(x_train_scaled, y_train)

# Make predictions on the scaled test set
y_pred_rbf_c100 = svm_rbf_c100.predict(x_test_scaled)

# Evaluate the model
accuracy_rbf_c100 = accuracy_score(y_test, y_pred_rbf_c100)
print(f'Accuracy with RBF kernel (C=100): {accuracy_rbf_c100:.4f}')
# Out:
# Accuracy with RBF kernel (C=100): 0.9821

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# Initialize the SVM classifier with RBF kernel and C=100
svm_rbf_c100 = SVC(kernel='rbf', C=1000, random_state=42)

# Train the model
svm_rbf_c100.fit(x_train_scaled, y_train)

# Make predictions on the scaled test set
y_pred_rbf_c100 = svm_rbf_c100.predict(x_test_scaled)

# Evaluate the model
accuracy_rbf_c100 = accuracy_score(y_test, y_pred_rbf_c100)
print(f'Accuracy with RBF kernel (C=100): {accuracy_rbf_c100:.4f}')
# Out:
# Accuracy with RBF kernel (C=100): 0.9802

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# Initialize the SVM classifier with a linear kernel and C=100
svm_linear_c100 = SVC(kernel='linear', C=100, random_state=42)

# Train the model
svm_linear_c100.fit(x_train_scaled, y_train)

# Make predictions on the scaled test set
y_pred_linear_c100 = svm_linear_c100.predict(x_test_scaled)

# Evaluate the model
accuracy_linear_c100 = accuracy_score(y_test, y_pred_linear_c100)
print(f'Accuracy with Linear kernel (C=100): {accuracy_linear_c100:.4f}')
# Out:
# Accuracy with Linear kernel (C=100): 0.9791

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# Initialize the SVM classifier with a linear kernel and C=1000
svm_linear_c1000 = SVC(kernel='linear', C=1000, random_state=42)

# Train the model
svm_linear_c1000.fit(x_train_scaled, y_train)

# Make predictions on the scaled test set
y_pred_linear_c1000 = svm_linear_c1000.predict(x_test_scaled)

# Evaluate the model
accuracy_linear_c1000 = accuracy_score(y_test, y_pred_linear_c1000)
print(f'Accuracy with Linear kernel (C=1000): {accuracy_linear_c1000:.4f}')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3029653320.py in <cell line: 0>()
#       6
#       7 # Train the model
# ----> 8 svm_linear_c1000.fit(x_train_scaled, y_train)
#       9
#      10 # Make predictions on the scaled test set
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py in fit(self, X, y, sample_weight)
#     256
#     257         seed = rnd.randint(np.iinfo("i").max)
# --> 258         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     259         # see comment on the other call to np.iinfo in this file
#     260
#
# ...

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# Initialize the SVM classifier with a polynomial kernel and C=1
svm_poly_c1 = SVC(kernel='poly', C=1, random_state=42)

# Train the model
svm_poly_c1.fit(x_train_scaled, y_train)

# Make predictions on the scaled test set
y_pred_poly_c1 = svm_poly_c1.predict(x_test_scaled)

# Evaluate the model
accuracy_poly_c1 = accuracy_score(y_test, y_pred_poly_c1)
print(f'Accuracy with Polynomial kernel (C=1): {accuracy_poly_c1:.4f}')

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# Initialize the SVM classifier with a polynomial kernel and C=100
svm_poly_c100 = SVC(kernel='poly', C=100, random_state=42)

# Train the model
svm_poly_c100.fit(x_train_scaled, y_train)

# Make predictions on the scaled test set
y_pred_poly_c100 = svm_poly_c100.predict(x_test_scaled)

# Evaluate the model
accuracy_poly_c100 = accuracy_score(y_test, y_pred_poly_c100)
print(f'Accuracy with Polynomial kernel (C=100): {accuracy_poly_c100:.4f}')

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# Initialize the SVM classifier with a polynomial kernel and C=1000
svm_poly_c1000 = SVC(kernel='poly', C=1000, random_state=42)

# Train the model
svm_poly_c1000.fit(x_train_scaled, y_train)

# Make predictions on the scaled test set
y_pred_poly_c1000 = svm_poly_c1000.predict(x_test_scaled)

# Evaluate the model
accuracy_poly_c1000 = accuracy_score(y_test, y_pred_poly_c1000)
print(f'Accuracy with Polynomial kernel (C=1000): {accuracy_poly_c1000:.4f}')

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# Initialize the SVM classifier with a linear kernel and C=1
svm_linear_c1 = SVC(kernel='linear', C=1, random_state=42)

# Train the model
svm_linear_c1.fit(x_train_scaled, y_train)

# Make predictions on the scaled test set
y_pred_linear_c1 = svm_linear_c1.predict(x_test_scaled)

# Evaluate the model
accuracy_linear_c1 = accuracy_score(y_test, y_pred_linear_c1)
print(f'Accuracy with Linear kernel (C=1): {accuracy_linear_c1:.4f}')
# Out:
# Accuracy with Linear kernel (C=1): 0.9788

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# Initialize the SVM classifier with a sigmoid kernel and C=1
svm_sigmoid_c1 = SVC(kernel='poly', C=1, random_state=42)

# Train the model
svm_sigmoid_c1.fit(x_train_scaled, y_train)

# Make predictions on the scaled test set
y_pred_sigmoid_c1 = svm_sigmoid_c1.predict(x_test_scaled)

# Evaluate the model
accuracy_sigmoid_c1 = accuracy_score(y_test, y_pred_sigmoid_c1)
print(f'Accuracy with Sigmoid kernel (C=1): {accuracy_sigmoid_c1:.4f}')
# Out:
# Accuracy with Sigmoid kernel (C=1): 0.9785

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# Initialize the SVM classifier with a sigmoid kernel and C=1
svm_sigmoid_c1 = SVC(kernel='poly', C=100, random_state=42)

# Train the model
svm_sigmoid_c1.fit(x_train_scaled, y_train)

# Make predictions on the scaled test set
y_pred_sigmoid_c1 = svm_sigmoid_c1.predict(x_test_scaled)

# Evaluate the model
accuracy_sigmoid_c1 = accuracy_score(y_test, y_pred_sigmoid_c1)
print(f'Accuracy with Sigmoid kernel (C=1): {accuracy_sigmoid_c1:.4f}')

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# Initialize the SVM classifier with a sigmoid kernel and C=1
svm_sigmoid_c1 = SVC(kernel='poly', C=1000, random_state=42)

# Train the model
svm_sigmoid_c1.fit(x_train_scaled, y_train)

# Make predictions on the scaled test set
y_pred_sigmoid_c1 = svm_sigmoid_c1.predict(x_test_scaled)

# Evaluate the model
accuracy_sigmoid_c1 = accuracy_score(y_test, y_pred_sigmoid_c1)
print(f'Accuracy with Sigmoid kernel (C=1): {accuracy_sigmoid_c1:.4f}')
# Out:
# Accuracy with Sigmoid kernel (C=1): 0.9810
